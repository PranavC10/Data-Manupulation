# %%
import pandas as pd

# %%
tips = pd.read_csv("Tips.csv")

# %%
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
#  total > = 25$ high
#  total < 25$ low

# %%
## if value is greater than or equal to 25$ it should return high or else low

# %%
def billValue(x):
    if (x >= 25):
        return ("high")
    
    elif x >10 :
        return "mid"
    else:
        return ("low")

# %%
billValue(20)
# Out:
# 'mid'

# %%
billValue(70)
# Out:
# 'high'

# %%
billValue(9)
# Out:
# 'low'

# %%
tips["cm_status"] = tips["total_bill"].apply(billValue) ## we are using total bill amount to create new col

# %%
tips.head(20)
# Out:
#     Unnamed: 0  total_bill   tip     sex smoker  day    time  size cm_status
# 0            0       16.99  1.01  Female     No  Sun  Dinner     2       mid
# 1            1       10.34  1.66    Male     No  Sun  Dinner     3       mid
# 2            2       21.01  3.50    Male     No  Sun  Dinner     3       mid
# 3            3       23.68  3.31    Male     No  Sun  Dinner     2       mid
# 4            4       24.59  3.61  Female     No  Sun  Dinner     4       mid
# 5            5       25.29  4.71    Male     No  Sun  Dinner     4      high
# 6            6        8.77  2.00    Male     No  Sun  Dinner     2       low
# 7            7       26.88  3.12    Male     No  Sun  Dinner     4      high
# 8            8       15.04  1.96    Male     No  Sun  Dinner     2       mid
# 9            9       14.78  3.23    Male     No  Sun  Dinner     2       mid
# 10          10       10.27  1.71    Male     No  Sun  Dinner     2       mid
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Name":["Xyz","PQR","jkl","iuy"],"age":[18,50,30,35]})

# %%
df
# Out:
#   Name  age
# 0  Xyz   18
# 1  PQR   50
# 2  jkl   30
# 3  iuy   35

# %%
### new col and if person is having age above 40 its should be senior , if its below junior

# %%
def check_age(x):
    if x <=40:
        return "Junior"
    
    else:
        return "Senior"

# %%
df["age_check"]=df["age"].apply(check_age)

# %%
df
# Out:
#   Name  age age_check
# 0  Xyz   18    Junior
# 1  PQR   50    Senior
# 2  jkl   30    Junior
# 3  iuy   35    Junior
