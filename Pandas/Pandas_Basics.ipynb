# %% [markdown]
# ![Pandas_logo.svg.png](attachment:Pandas_logo.svg.png)

# %% [markdown]
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# In computer programming, pandas is a software library written for the Python programming language for data manipulation and analysis. ... The name is derived from the term "panel data", an econometrics term for data sets that include observations over multiple time periods for the same individuals.

# %% [markdown]
# Timeline
#
# 2008: Development of pandas started
#
# 2009: pandas becomes open source
#
# 2012: First edition of Python for Data Analysis is published
#
# 2015: pandas becomes a NumFOCUS sponsored project
#
# 2018: First in-person core developer sprint

# %% [markdown]
# ## Mission
# pandas aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.
#
# ## Vision
#
# A world where data analytics and manipulation software is:
#
# Accessible to everyone
#
# Free for users to use and modify
#
# Flexible
#
# Powerful
#
# Easy to use
#
# Fast
#
# ## Values
# Is in the core of pandas to be respectful and welcoming with everybody, users, contributors and the broader community. Regardless of level of experience, gender, gender identity and expression, sexual orientation, disability, personal appearance, body size, race, ethnicity, age, religion, or nationality.

# %% [markdown]
# You can always refer to official documentation for performing operation without remembering the codes
#
# Pandas Documentation: https://pandas.pydata.org/

# %%
##https://www.nfl.com/stats/player-stats/

# %%
# !pip install pandas

# %%
import pandas as pd  ## i want to use pandas just load it for me and i will using pd to call it instead of pandas

# %%
pd.__version__
# Out:
# '1.4.2'

# %% [markdown]
# ### Reading CSV files

# %%
df=pd.read_csv("Test.csv")

# %%
df
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %% [markdown]
# ### Loading file from other location

# %%
pwd()
# Out:
# 'C:\\Users\\Pranav\\Upgrad\\UpKh_Python\\Pandas'

# %%
df2=pd.read_csv(r"C:\Users\Pranav\OneDrive\Desktop\Test_desktop.csv")  
## you might get error just change the location according to your pc
## to load file from different location get the complete path

# %%
df3=pd.read_csv("test.tsv") ## pandas get me the file which is seprated by ","

# %%
df3
# Out:
#   name\tmaths\tphy\tresult
# 0        tom\t80\t70\tPass
# 1       jhon\t75\t67\tPass
# 2        max\t28\t55\tFail
# 3       mike\t88\t70\tPass
# 4     robert\t23\t29\tFail
# 5      aaron\t95\t89\tPass

# %%
df3=pd.read_csv("test.tsv",sep = "\t") ## pandas get me the file which is seprated by "\t" tab

# %%
df3
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %%
df4 = pd.read_table("test.tsv")

# %%
df4
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %%
df5 = pd.read_table("test.csv")

# %%
df5
# Out:
#   name,maths,phy,result
# 0        tom,80,70,Pass
# 1       jhon,75,67,Pass
# 2        max,28,55,Fail
# 3       mike,88,70,Pass
# 4     robert,23,29,Fail
# 5      aaron,95,89,Pass

# %%
df5 = pd.read_table("test.csv",sep=",")

# %%
df5
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %% [raw]
# ## 1st if file is in same folder as you are working in
#
# read file using :
# df=pd.read_csv("filename.extension")

# %% [raw]
# 2nd case , if file is in some other folder or path
#
# ## go to the file right click it and copy the path
# df = pd.read_csv("paste the path including file name & extension")

# %%
## Enable extension view from windows view in explorer

# %%
pwd()
# Out:
# 'C:\\Users\\Pranav\\Upgrad\\UpKh_Python\\Pandas'

# %% [markdown]
# ### Reading excel sheet

# %%
df6 = pd.read_excel("Test_excel.xlsx",sheet_name = "marks")

# %%
df6
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %%
## load roll_no sheet from Test_excel file

# %%
df7 = pd.read_excel("Test_excel.xlsx",sheet_name = "roll_no")

# %%
df7
# Out:
#    roll no    name
# 0        1     tom
# 1        2    jhon
# 2        3     max
# 3        4    mike
# 4        5  robert
# 5        6   aaron

# %%
df8=pd.read_csv("Test.csv",header = None) ## dont use first row as header names

# %%
df8
# Out:
#         0      1    2       3
# 0    name  maths  phy  result
# 1     tom     80   70    Pass
# 2    jhon     75   67    Pass
# 3     max     28   55    Fail
# 4    mike     88   70    Pass
# 5  robert     23   29    Fail
# 6   aaron     95   89    Pass

# %%
df9=pd.read_csv("Test.csv")
df9
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %%
type(df9) ## Pandas data type is dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
tips=pd.read_csv("tips.csv")

# %%
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tips.head() ## print 1st  5 rows
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head(2) ## print 1st  2 rows
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.tail() ## its printing last 5 records / rows
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.tail(8)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 236         236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237         237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238         238       35.83  4.67  Female     No   Sat  Dinner     3
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips[["total_bill","tip"]] ### dataframe[ pass the list of cols you want to view]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
tips[["total_bill","size"]]
# Out:
#      total_bill  size
# 0         16.99     2
# 1         10.34     3
# 2         21.01     3
# 3         23.68     2
# 4         24.59     4
# ..          ...   ...
# 239       29.03     3
# 240       27.18     2
# 241       22.67     2
# 242       17.82     2
# 243       18.78     2
#
# [244 rows x 2 columns]

# %%
tips["day"] ## pandas string is object datatype
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: object

# %%
type(tips["day"]) ## series is also datatype in pandas it mostly referes to single column ## series
# Out:
# pandas.core.series.Series

# %%
tips.info() ## information about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  244 non-null    int64
#  1   total_bill  244 non-null    float64
#  2   tip         244 non-null    float64
#  3   sex         244 non-null    object
#  4   smoker      244 non-null    object
#  5   day         244 non-null    object
#  6   time        244 non-null    object
#  7   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 15.4+ KB

# %%
del tips["Unnamed: 0"]

# %%
tips.describe() ## descriptive stats of dataframe
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### Key take aways
#
# 1. Average bill amount is 20$ and yes we have some high paying customer as well.
#
# 2. Majority of customers are coming in pairs (2) which means we need more 2 table seater

# %%
(tips["size"].value_counts()/tips.shape[0] ) * 100 ## you will understand it further
# Out:
# 2    63.934426
# 3    15.573770
# 4    15.163934
# 5     2.049180
# 1     1.639344
# 6     1.639344
# Name: size, dtype: float64

# %%
tips.shape ## (Row counts , col counts)
# Out:
# (244, 7)

# %%
tips.shape[0] ## rows
# Out:
# 244

# %% [markdown]
# ### Pandas can get data from html also

# %%
player_info= pd.read_html("https://www.nfl.com/stats/player-stats/")

# %%
player_info
# Out:
# [              Player  Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT   Rate  1st  \
#  0         Josh Allen      1651      8.3  199  133   66.8  14    4  107.4   78
#  1       Carson Wentz      1489      6.4  232  144   62.1  10    6   84.1   68
#  2     Justin Herbert      1478      7.4  200  133   66.5  10    2  100.8   68
#  3          Tom Brady      1409      6.8  207  141   68.1   7    1   96.5   72
#  4    Patrick Mahomes      1398      7.4  189  126   66.7  15    2  110.5   80
#  5          Matt Ryan      1376      7.1  195  128   65.6   5    7   79.8   69
#  6        Jalen Hurts      1359      8.6  159  108   67.9   4    2   97.4   61
#  7         Jared Goff      1355      7.3  186  111   59.7  11    4   92.9   65
#  8       Kirk Cousins      1327      6.7  198  131   66.2   7    5   86.4   75
#  9   Matthew Stafford      1323      6.9  192  134   69.8   5    7   82.4   65
#  10        Joe Burrow      1316      6.9  191  124   64.9   9    5   89.7   67
# ...

# %%
type(player_info) ## Pandas mostly returns dataframe or series
# Out:
# list

# %%
player_info[0]
# Out:
#               Player  Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT   Rate  1st  \
# 0         Josh Allen      1651      8.3  199  133   66.8  14    4  107.4   78
# 1       Carson Wentz      1489      6.4  232  144   62.1  10    6   84.1   68
# 2     Justin Herbert      1478      7.4  200  133   66.5  10    2  100.8   68
# 3          Tom Brady      1409      6.8  207  141   68.1   7    1   96.5   72
# 4    Patrick Mahomes      1398      7.4  189  126   66.7  15    2  110.5   80
# 5          Matt Ryan      1376      7.1  195  128   65.6   5    7   79.8   69
# 6        Jalen Hurts      1359      8.6  159  108   67.9   4    2   97.4   61
# 7         Jared Goff      1355      7.3  186  111   59.7  11    4   92.9   65
# 8       Kirk Cousins      1327      6.7  198  131   66.2   7    5   86.4   75
# 9   Matthew Stafford      1323      6.9  192  134   69.8   5    7   82.4   65
# 10        Joe Burrow      1316      6.9  191  124   64.9   9    5   89.7   67
# ...

# %%
len(player_info)
# Out:
# 1

# %%
player_df=player_info[0]

# %%
player_df.head(2)
# Out:
#          Player  Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT   Rate  1st  \
# 0    Josh Allen      1651      8.3  199  133   66.8  14    4  107.4   78
# 1  Carson Wentz      1489      6.4  232  144   62.1  10    6   84.1   68
#
#    1st%  20+  40+  Lng  Sck  SckY
# 0  39.2   20    6   98    8    39
# 1  29.3   18    4   75   23   140

# %%
player_df.to_csv("My_data.csv",index = False ) ## if you just give file name it will save in PWD()

# %%
player_df.to_excel("My_data.xlsx",index = False )

# %%
player_df.to_csv(r"C:\Users\Pranav\OneDrive/desktop/My_data.csv",index = False )
## if you complete location it will save at that location
## you might get error just change the location according to your pc

# %% [markdown]
# ### Maths/ stats operation dataframe

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips["tip"].mean() ## DataFramename["Colname"].mathfunc()
# Out:
# 2.9982786885245902

# %%
tips["tip"].median()
# Out:
# 2.9

# %%
tips["tip"].mode()
# Out:
# 0    2.0
# Name: tip, dtype: float64

# %%
tips["tip"].std()
# Out:
# 1.3836381890011826

# %%
tips["tip"].var()
# Out:
# 1.9144546380624725

# %%
tips["time"].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
tips["time"].nunique()
# Out:
# 2

# %%
tips["time"].mode() ## what it means ?
# Out:
# 0    Dinner
# Name: time, dtype: object

# %% [markdown]
# Majority of the customers are coming at dinner time

# %%
tips["customer_spend"] = tips["total_bill"] + tips["tip"] ## datafrae["new_col_name"] = maths operation on dataframe cols

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  customer_spend
# 0       16.99  1.01  Female     No  Sun  Dinner     2            18.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3            12.0

# %%
### You need to create new col name it as individual_customer_share  = customer spend / size

# %%
tips["individual_customer_share"] = tips["customer_spend"] / tips["size"]

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  customer_spend  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2            18.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3            12.0
#
#    individual_customer_share
# 0                        9.0
# 1                        4.0

# %%
df.drop("phy",axis = 1) ## Axis - 0 means rows and axis - 1 means col  ## del df["phy"] if you 
## miss the col name it will delete the complete dataframe
# Out:
#      name  maths result
# 0     tom     80   Pass
# 1    jhon     75   Pass
# 2     max     28   Fail
# 3    mike     88   Pass
# 4  robert     23   Fail
# 5   aaron     95   Pass

# %%
df_without_phy = df.drop("phy",axis = 1)

# %%
df_without_phy
# Out:
#      name  maths result
# 0     tom     80   Pass
# 1    jhon     75   Pass
# 2     max     28   Fail
# 3    mike     88   Pass
# 4  robert     23   Fail
# 5   aaron     95   Pass

# %%
df
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %% [markdown]
# ### if you want to make changes in same dataframe

# %%
df
# Out:
#      name  maths  phy result
# 0     tom     80   70   Pass
# 1    jhon     75   67   Pass
# 2     max     28   55   Fail
# 3    mike     88   70   Pass
# 4  robert     23   29   Fail
# 5   aaron     95   89   Pass

# %%
df.drop("phy",axis = 1,inplace = True) ## inplace = True means make the change in same place / dataframe

## equivalent code which will give same result df = df.drop("phy",axis = 1)

# %%
df
# Out:
#      name  maths result
# 0     tom     80   Pass
# 1    jhon     75   Pass
# 2     max     28   Fail
# 3    mike     88   Pass
# 4  robert     23   Fail
# 5   aaron     95   Pass

# %%
df.drop("maths",axis = 1,inplace = False) ## it is same as df.drop("maths",axis = 1) default value of inplace is false
# Out:
#      name result
# 0     tom   Pass
# 1    jhon   Pass
# 2     max   Fail
# 3    mike   Pass
# 4  robert   Fail
# 5   aaron   Pass

# %%
df
# Out:
#      name  maths result
# 0     tom     80   Pass
# 1    jhon     75   Pass
# 2     max     28   Fail
# 3    mike     88   Pass
# 4  robert     23   Fail
# 5   aaron     95   Pass

# %%
df.drop(2,axis = 0) ## axis = 0 means i want to delete row
# Out:
#      name  maths result
# 0     tom     80   Pass
# 1    jhon     75   Pass
# 3    mike     88   Pass
# 4  robert     23   Fail
# 5   aaron     95   Pass

# %%
df
# Out:
#      name  maths result
# 0     tom     80   Pass
# 1    jhon     75   Pass
# 2     max     28   Fail
# 3    mike     88   Pass
# 4  robert     23   Fail
# 5   aaron     95   Pass

# %%
df["default"] = 0

# %%
df
# Out:
#      name  maths result  default
# 0     tom     80   Pass        0
# 1    jhon     75   Pass        0
# 2     max     28   Fail        0
# 3    mike     88   Pass        0
# 4  robert     23   Fail        0
# 5   aaron     95   Pass        0

# %%
df["result"].value_counts()
# Out:
# Pass    4
# Fail    2
# Name: result, dtype: int64

# %% [markdown]
# ### Filtering  the DataFrame

# %%
df[df["result"] == "Pass"] ### dataframe[put condition]
# Out:
#     name  maths result  default
# 0    tom     80   Pass        0
# 1   jhon     75   Pass        0
# 3   mike     88   Pass        0
# 5  aaron     95   Pass        0

# %%
df[df["result"] == "Fail"] ### dataframe[put condition]
# Out:
#      name  maths result  default
# 2     max     28   Fail        0
# 4  robert     23   Fail        0

# %%
## get me the students which have scored > 80 marks in maths

# %%
df[df["maths"] >80 ] ##### dataframe[condition]
# Out:
#     name  maths result  default
# 3   mike     88   Pass        0
# 5  aaron     95   Pass        0

# %%
df
# Out:
#      name  maths result  default
# 0     tom     80   Pass        0
# 1    jhon     75   Pass        0
# 2     max     28   Fail        0
# 3    mike     88   Pass        0
# 4  robert     23   Fail        0
# 5   aaron     95   Pass        0

# %%
df["maths"] >80  ## condition is nothing but True and false values which tell pandas dataframw which rows to print
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: maths, dtype: bool

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  customer_spend  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2           18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3           12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3           24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2           26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4           28.20
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2           19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2           21.78
#
#      individual_customer_share
# 0                        9.000
# ...

# %%
## I want to get those customer which smoke and paid the tip above 2$

# %%
tips[(tips["smoker"] == "Yes") & (tips["tip"] > 2)]  ## tips[ (condition 1) & (condition 2)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  customer_spend  \
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4           41.01
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2           23.50
# 63        18.29  3.76    Male    Yes  Sat  Dinner     4           22.05
# 69        15.01  2.09    Male    Yes  Sat  Dinner     2           17.10
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2           30.00
# ..          ...   ...     ...    ...  ...     ...   ...             ...
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2           16.90
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2           18.77
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2           25.00
# 231       15.69  3.00    Male    Yes  Sat  Dinner     3           18.69
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2           18.53
#
#      individual_customer_share
# 56                     10.2525
# 60                     11.7500
# ...

# %%
## I want to get those customer which smoke or paid the tip above 2$

# %%
tips[(tips["smoker"] == "Yes") | (tips["tip"] > 2)]  ## tips[ (condition 1) | (condition 2)]  | = or
# Out:
#      total_bill   tip     sex smoker   day    time  size  customer_spend  \
# 2         21.01  3.50    Male     No   Sun  Dinner     3           24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2           26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4           28.20
# 5         25.29  4.71    Male     No   Sun  Dinner     4           30.00
# 7         26.88  3.12    Male     No   Sun  Dinner     4           30.00
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 238       35.83  4.67  Female     No   Sat  Dinner     3           40.50
# 239       29.03  5.92    Male     No   Sat  Dinner     3           34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           24.67
# 243       18.78  3.00  Female     No  Thur  Dinner     2           21.78
#
#      individual_customer_share
# 2                        8.170
# ...

# %%
tips[~(tips["smoker"] == "Yes") & ~(tips["tip"] > 2)]  ##  ~ not 
## ## I want to get those customer which not  smoke and not paid the tip above 2$

## tips[(tips["smoker"] == "No") & (tips["tip"] <= 2)]  ## Same as above code
# Out:
#      total_bill   tip     sex smoker   day    time  size  customer_spend  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2           18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3           12.00
# 6          8.77  2.00    Male     No   Sun  Dinner     2           10.77
# 8         15.04  1.96    Male     No   Sun  Dinner     2           17.00
# 10        10.27  1.71    Male     No   Sun  Dinner     2           11.98
# 12        15.42  1.57    Male     No   Sun  Dinner     2           16.99
# 16        10.33  1.67  Female     No   Sun  Dinner     3           12.00
# 26        13.37  2.00    Male     No   Sat  Dinner     2           15.37
# 27        12.69  2.00    Male     No   Sat  Dinner     2           14.69
# 30         9.55  1.45    Male     No   Sat  Dinner     2           11.00
# 36        16.31  2.00    Male     No   Sat  Dinner     3           18.31
# 43         9.68  1.32    Male     No   Sun  Dinner     2           11.00
# ...
